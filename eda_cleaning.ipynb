# %%
from d100project.data._load_data import load_data
from d100project.preprocessing._dtype import dtype

# Load the dataset
df = load_data()

# Display column names and the data types of each column
dtype(df)
# Out:
# ===== Data Types =====
# budget: int64
# genres: object
# homepage: object
# id: int64
# keywords: object
# original_language: object
# original_title: object
# overview: object
# popularity: float64
# production_companies: object
# production_countries: object
# release_date: object
# revenue: int64
# runtime: float64
# spoken_languages: object
# status: object
# tagline: object
# title: object
# vote_average: float64
# vote_count: int64

# %%
from d100project.preprocessing._descript_stats import descript_stats
from d100project.data._load_data import load_data

# Load the dataset
df = load_data()

# Display column names and the data types of each column
descript_stats(df)
# Out:
# ===== Descriptive Statistics =====
#               budget                         genres  \
# count   4.803000e+03                           4803
# unique           NaN                           1175
# top              NaN  [{"id": 18, "name": "Drama"}]
# freq             NaN                            370
# mean    2.904504e+07                            NaN
# std     4.072239e+07                            NaN
# min     0.000000e+00                            NaN
# 25%     7.900000e+05                            NaN
# 50%     1.500000e+07                            NaN
# 75%     4.000000e+07                            NaN
# max     3.800000e+08                            NaN
#
#                                  homepage             id keywords  \
# count                                1712    4803.000000     4803
# unique                               1691            NaN     4222
# top     http://www.missionimpossible.com/            NaN       []
# freq                                    4            NaN      412
# mean                                  NaN   57165.484281      NaN
# std                                   NaN   88694.614033      NaN
# min                                   NaN       5.000000      NaN
# 25%                                   NaN    9014.500000      NaN
# 50%                                   NaN   14629.000000      NaN
# 75%                                   NaN   58610.500000      NaN
# max                                   NaN  459488.000000      NaN
#
#        original_language original_title  \
# count               4803           4803
# unique                37           4801
# top                   en         Batman
# freq                4505              2
# mean                 NaN            NaN
# std                  NaN            NaN
# min                  NaN            NaN
# 25%                  NaN            NaN
# 50%                  NaN            NaN
# 75%                  NaN            NaN
# max                  NaN            NaN
#
#                                                  overview   popularity  \
# count                                                4800  4803.000000
# unique                                               4800          NaN
# top     In the 22nd century, a paraplegic Marine is di...          NaN
# freq                                                    1          NaN
# mean                                                  NaN    21.492301
# std                                                   NaN    31.816650
# min                                                   NaN     0.000000
# 25%                                                   NaN     4.668070
# 50%                                                   NaN    12.921594
# 75%                                                   NaN    28.313505
# max                                                   NaN   875.581305
#
#        production_companies  \
# count                  4803
# unique                 3697
# top                      []
# freq                    351
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN
#
#                                      production_countries release_date  \
# count                                                4803         4802
# unique                                                469         3280
# top     [{"iso_3166_1": "US", "name": "United States o...   2006-01-01
# freq                                                 2977           10
# mean                                                  NaN          NaN
# std                                                   NaN          NaN
# min                                                   NaN          NaN
# 25%                                                   NaN          NaN
# 50%                                                   NaN          NaN
# 75%                                                   NaN          NaN
# max                                                   NaN          NaN
#
#              revenue      runtime                          spoken_languages  \
# count   4.803000e+03  4801.000000                                      4803
# unique           NaN          NaN                                       544
# top              NaN          NaN  [{"iso_639_1": "en", "name": "English"}]
# freq             NaN          NaN                                      3171
# mean    8.226064e+07   106.875859                                       NaN
# std     1.628571e+08    22.611935                                       NaN
# min     0.000000e+00     0.000000                                       NaN
# 25%     0.000000e+00    94.000000                                       NaN
# 50%     1.917000e+07   103.000000                                       NaN
# 75%     9.291719e+07   118.000000                                       NaN
# max     2.787965e+09   338.000000                                       NaN
#
#           status                 tagline     title  vote_average    vote_count
# count       4803                    3959      4803   4803.000000   4803.000000
# unique         3                    3944      4800           NaN           NaN
# top     Released  Based on a true story.  The Host           NaN           NaN
# freq        4795                       3         2           NaN           NaN
# mean         NaN                     NaN       NaN      6.092172    690.217989
# std          NaN                     NaN       NaN      1.194612   1234.585891
# min          NaN                     NaN       NaN      0.000000      0.000000
# 25%          NaN                     NaN       NaN      5.600000     54.000000
# 50%          NaN                     NaN       NaN      6.200000    235.000000
# 75%          NaN                     NaN       NaN      6.800000    737.000000
# max          NaN                     NaN       NaN     10.000000  13752.000000

# %%
from d100project.preprocessing._descript_stats_without_zeros import descript_stats_without_zeros
from d100project.data._load_data import load_data

# Load the dataset
df = load_data()

# Display column names and the data types of each column
descript_stats_without_zeros(df)
# Out:
# ===== Descriptive Statistics (Zero Treated as Missing) =====
#               budget                         genres  \
# count   3.766000e+03                           4803
# unique           NaN                           1175
# top              NaN  [{"id": 18, "name": "Drama"}]
# freq             NaN                            370
# mean    3.704284e+07                            NaN
# std     4.264651e+07                            NaN
# min     1.000000e+00                            NaN
# 25%     8.000000e+06                            NaN
# 50%     2.300000e+07                            NaN
# 75%     5.000000e+07                            NaN
# max     3.800000e+08                            NaN
#
#                                  homepage             id keywords  \
# count                                1712    4803.000000     4803
# unique                               1691            NaN     4222
# top     http://www.missionimpossible.com/            NaN       []
# freq                                    4            NaN      412
# mean                                  NaN   57165.484281      NaN
# std                                   NaN   88694.614033      NaN
# min                                   NaN       5.000000      NaN
# 25%                                   NaN    9014.500000      NaN
# 50%                                   NaN   14629.000000      NaN
# 75%                                   NaN   58610.500000      NaN
# max                                   NaN  459488.000000      NaN
#
#        original_language original_title  \
# count               4803           4803
# unique                37           4801
# top                   en         Batman
# freq                4505              2
# mean                 NaN            NaN
# std                  NaN            NaN
# min                  NaN            NaN
# 25%                  NaN            NaN
# 50%                  NaN            NaN
# 75%                  NaN            NaN
# max                  NaN            NaN
#
#                                                  overview   popularity  \
# count                                                4800  4802.000000
# unique                                               4800          NaN
# top     In the 22nd century, a paraplegic Marine is di...          NaN
# freq                                                    1          NaN
# mean                                                  NaN    21.496776
# std                                                   NaN    31.818451
# min                                                   NaN     0.000372
# 25%                                                   NaN     4.671734
# 50%                                                   NaN    12.924931
# 75%                                                   NaN    28.332017
# max                                                   NaN   875.581305
#
#        production_companies  \
# count                  4803
# unique                 3697
# top                      []
# freq                    351
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN
#
#                                      production_countries release_date  \
# count                                                4803         4802
# unique                                                469         3280
# top     [{"iso_3166_1": "US", "name": "United States o...   2006-01-01
# freq                                                 2977           10
# mean                                                  NaN          NaN
# std                                                   NaN          NaN
# min                                                   NaN          NaN
# 25%                                                   NaN          NaN
# 50%                                                   NaN          NaN
# 75%                                                   NaN          NaN
# max                                                   NaN          NaN
#
#              revenue      runtime                          spoken_languages  \
# count   3.376000e+03  4766.000000                                      4803
# unique           NaN          NaN                                       544
# top              NaN          NaN  [{"iso_639_1": "en", "name": "English"}]
# freq             NaN          NaN                                      3171
# mean    1.170314e+08   107.660722                                       NaN
# std     1.834831e+08    20.749424                                       NaN
# min     5.000000e+00    14.000000                                       NaN
# 25%     1.535290e+07    94.000000                                       NaN
# 50%     5.175184e+07   104.000000                                       NaN
# 75%     1.401651e+08   118.000000                                       NaN
# max     2.787965e+09   338.000000                                       NaN
#
#           status                 tagline     title  vote_average    vote_count
# count       4803                    3959      4803   4740.000000   4741.000000
# unique         3                    3944      4800           NaN           NaN
# top     Released  Based on a true story.  The Host           NaN           NaN
# freq        4795                       3         2           NaN           NaN
# mean         NaN                     NaN       NaN      6.173143    699.244252
# std          NaN                     NaN       NaN      0.972684   1240.091227
# min          NaN                     NaN       NaN      0.500000      1.000000
# 25%          NaN                     NaN       NaN      5.600000     58.000000
# 50%          NaN                     NaN       NaN      6.200000    242.000000
# 75%          NaN                     NaN       NaN      6.800000    750.000000
# max          NaN                     NaN       NaN     10.000000  13752.000000

# %%
from d100project.plotting._plot_hist_replace_zeros import plot_hist_replace_zeros
from d100project.data._load_data import load_data

# load dataset
df = load_data()

# plot budget
plot_hist_replace_zeros(df, 'revenue')

# %%
from d100project.plotting._plot_hist_replace_zeros import plot_hist_replace_zeros
from d100project.data._load_data import load_data

# load dataset
df = load_data()

# plot budget
plot_hist_replace_zeros(df, 'budget')

# %%
from d100project.plotting._plot_hist_replace_zeros import plot_hist_replace_zeros
from d100project.data._load_data import load_data

# load dataset
df = load_data()

# plot budget
plot_hist_replace_zeros(df, 'runtime')

# %%
from d100project.preprocessing._extract_name import extract_name
from d100project.preprocessing._tally_names import tally_names
from d100project.data._load_data import load_data

# load dataset
df = load_data()

# Extract genre names
df = extract_name(df, "genres")

# For genres
genre_tally = tally_names(df, "genres_list")
genre_tally.head(25)  # top 20 genres (only 20 genres exist in dataset)
# Out:
#                Item  Count
# 0             Drama   2297
# 1            Comedy   1722
# 2          Thriller   1274
# 3            Action   1154
# 4           Romance    894
# 5         Adventure    790
# 6             Crime    696
# 7   Science Fiction    535
# 8            Horror    519
# 9            Family    513
# 10          Fantasy    424
# 11          Mystery    348
# 12        Animation    234
# 13          History    197
# 14            Music    185
# 15              War    144
# 16      Documentary    110
# 17          Western     82
# 18          Foreign     34
# 19         TV Movie      8

# %%
from d100project.preprocessing._extract_name import extract_name
from d100project.preprocessing._tally_names import tally_names
from d100project.data._load_data import load_data

# load dataset
df = load_data()

# Extract production_companies names
df = extract_name(df, "production_companies")

# For production_companies
genre_tally = tally_names(df, "production_companies_list")
genre_tally.head(10)  # top 10 production_companies
# Out:
#                                      Item  Count
# 0                            Warner Bros.    319
# 1                      Universal Pictures    311
# 2                      Paramount Pictures    285
# 3  Twentieth Century Fox Film Corporation    222
# 4                       Columbia Pictures    201
# 5                         New Line Cinema    165
# 6               Metro-Goldwyn-Mayer (MGM)    122
# 7                     Touchstone Pictures    118
# 8                    Walt Disney Pictures    114
# 9                        Relativity Media    102

# %%
from d100project.preprocessing._extract_name import extract_name
from d100project.preprocessing._tally_names import tally_names
from d100project.data._load_data import load_data

# load dataset
df = load_data()

# Extract production_countries names
df = extract_name(df, "production_countries")

# For production_countries
genre_tally = tally_names(df, "production_countries_list")
genre_tally.head(10)  # top 10 production_countries
# Out:
#                        Item  Count
# 0  United States of America   3956
# 1            United Kingdom    636
# 2                   Germany    324
# 3                    France    306
# 4                    Canada    261
# 5                 Australia    110
# 6                     Italy     72
# 7                     Spain     71
# 8                     China     59
# 9                     Japan     58

# %%
from d100project.preprocessing._extract_name import extract_name
from d100project.preprocessing._tally_names import tally_names
from d100project.data._load_data import load_data

# load dataset
df = load_data()

# Extract spoken_languages names
df = extract_name(df, "spoken_languages")

# For spoken_languages
genre_tally = tally_names(df, "spoken_languages_list")
genre_tally.head(10)  # top 10 spoken_languages
# Out:
#         Item  Count
# 0    English   4485
# 1   Français    437
# 2    Español    351
# 3    Deutsch    262
# 4   Italiano    188
# 5    Pусский    185
# 6        普通话    107
# 7        日本語     97
# 8  Português     68
# 9    العربية     67

# %%
from d100project.preprocessing._tally_strings import tally_strings
from d100project.data._load_data import load_data

# load dataset
df = load_data()

# For original_language
tally_strings(df, "original_language")
# Out:
#   String  Count
# 0      e   4569
# 1      n   4523
# 2      r     86
# 3      f     75
# 4      h     53
# 5      s     42
# 6      i     37
# 7      d     36
# 8      a     32
# 9      t     30

# %%
from d100project.preprocessing._extract_name import extract_name
from d100project.preprocessing._count_empty_lists import count_empty_lists
from d100project.data._load_data import load_data

# load dataset
df = load_data()

df = extract_name(df, "genres")
count_empty_lists(df, "genres")
# Out:
# Number of missing genres: 28

# %%
from d100project.preprocessing._extract_name import extract_name
from d100project.preprocessing._count_empty_lists import count_empty_lists
from d100project.data._load_data import load_data

# load dataset
df = load_data()

df = extract_name(df, "production_companies")
count_empty_lists(df, "production_companies")
# Out:
# Number of missing production_companies: 351

# %%
from d100project.preprocessing._extract_name import extract_name
from d100project.preprocessing._count_empty_lists import count_empty_lists
from d100project.data._load_data import load_data

# load dataset
df = load_data()

df = extract_name(df, "production_countries")
count_empty_lists(df, "production_countries")
# Out:
# Number of missing production_countries: 174

# %%
from d100project.preprocessing._extract_name import extract_name
from d100project.preprocessing._count_empty_lists import count_empty_lists
from d100project.data._load_data import load_data

# load dataset
df = load_data()

df = extract_name(df, "spoken_languages")
count_empty_lists(df, "spoken_languages")
# Out:
# Number of missing spoken_languages: 86
