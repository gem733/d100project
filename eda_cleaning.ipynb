# %%
from d100project.data._load_data import load_data
from d100project.eda._dtype import dtype

# Load the dataset
df = load_data()

# Display column names and the data types of each column
dtype(df)
# Out:
# ===== Data Types =====
# budget: int64
# genres: object
# homepage: object
# id: int64
# keywords: object
# original_language: object
# original_title: object
# overview: object
# popularity: float64
# production_companies: object
# production_countries: object
# release_date: object
# revenue: int64
# runtime: float64
# spoken_languages: object
# status: object
# tagline: object
# title: object
# vote_average: float64
# vote_count: int64

# %%
from d100project.eda._descriptive_stats_table import descriptive_stats_table
from d100project.data._load_data import load_data

# Load the dataset
df = load_data()

# Display column names and the data types of each column
descriptive_stats_table(df)
# Out:
#                        count unique  \
# budget                3766.0    NaN
# genres                  4803   1175
# homepage                1712   1691
# id                    4803.0    NaN
# keywords                4803   4222
# original_language       4803     37
# original_title          4803   4801
# overview                4800   4800
# popularity            4802.0    NaN
# production_companies    4803   3697
# production_countries    4803    469
# release_date            4802   3280
# revenue               3376.0    NaN
# runtime               4766.0    NaN
# spoken_languages        4803    544
# status                  4803      3
# tagline                 3959   3944
# title                   4803   4800
# vote_average          4740.0    NaN
# vote_count            4741.0    NaN
#
#                                                                     top  freq  \
# budget                                                              NaN   NaN
# ...

# %%
from d100project.eda._plot_hist_replace_zeros import plot_hist_replace_zeros
from d100project.data._load_data import load_data

# load dataset
df = load_data()

# plot revenue
plot_hist_replace_zeros(df, 'revenue')

# %%
from d100project.eda._plot_hist_replace_zeros import plot_hist_replace_zeros
from d100project.data._load_data import load_data

# load dataset
df = load_data()

# plot budget
plot_hist_replace_zeros(df, 'budget')

# %%
from d100project.eda._plot_hist_replace_zeros import plot_hist_replace_zeros
from d100project.data._load_data import load_data

# load dataset
df = load_data()

# plot runtime
plot_hist_replace_zeros(df, 'runtime')

# %%
from d100project.eda._plot_dates import plot_dates
from d100project.data._load_data import load_data

# load dataset
df = load_data()

plot_dates(df, 'release_date')

# %%
from d100project.eda._scatter_plot import scatter_plot
from d100project.data._load_data import load_data

# load dataset
df = load_data()

# plot budget vs revenue
scatter_plot(df, 'revenue' , 'budget')

# %%
from d100project.eda._scatter_plot import scatter_plot
from d100project.data._load_data import load_data

# load dataset
df = load_data()

# plot budget vs runtime
scatter_plot(df, 'revenue' , 'runtime')

# %%
from d100project.eda._extract_name import extract_name
from d100project.eda._tally_names import tally_names
from d100project.data._load_data import load_data

# load dataset
df = load_data()

# Extract genre names
df = extract_name(df, "genres")

# For genres
genre_tally = tally_names(df, "genres_list")
genre_tally.head(25)  # top 20 genres (only 20 genres exist in dataset)
# Out:
#               Value  Count
# 0             Drama   2297
# 1            Comedy   1722
# 2          Thriller   1274
# 3            Action   1154
# 4           Romance    894
# 5         Adventure    790
# 6             Crime    696
# 7   Science Fiction    535
# 8            Horror    519
# 9            Family    513
# 10          Fantasy    424
# 11          Mystery    348
# 12        Animation    234
# 13          History    197
# 14            Music    185
# 15              War    144
# 16      Documentary    110
# 17          Western     82
# 18          Foreign     34
# 19         TV Movie      8

# %%
from d100project.eda._extract_name import extract_name
from d100project.eda._tally_names import tally_names
from d100project.data._load_data import load_data

# load dataset
df = load_data()

# Extract production_companies names
df = extract_name(df, "production_companies")

# For production_companies
genre_tally = tally_names(df, "production_companies_list")
genre_tally.head(10)  # top 10 production_companies
# Out:
#                                     Value  Count
# 0                            Warner Bros.    319
# 1                      Universal Pictures    311
# 2                      Paramount Pictures    285
# 3  Twentieth Century Fox Film Corporation    222
# 4                       Columbia Pictures    201
# 5                         New Line Cinema    165
# 6               Metro-Goldwyn-Mayer (MGM)    122
# 7                     Touchstone Pictures    118
# 8                    Walt Disney Pictures    114
# 9                        Relativity Media    102

# %%
from d100project.eda._extract_name import extract_name
from d100project.eda._tally_names import tally_names
from d100project.data._load_data import load_data

# load dataset
df = load_data()

# Extract production_countries names
df = extract_name(df, "production_countries")

# For production_countries
genre_tally = tally_names(df, "production_countries_list")
genre_tally.head(10)  # top 10 production_countries
# Out:
#                       Value  Count
# 0  United States of America   3956
# 1            United Kingdom    636
# 2                   Germany    324
# 3                    France    306
# 4                    Canada    261
# 5                 Australia    110
# 6                     Italy     72
# 7                     Spain     71
# 8                     China     59
# 9                     Japan     58

# %%
from d100project.eda._extract_name import extract_name
from d100project.eda._tally_names import tally_names
from d100project.data._load_data import load_data

# load dataset
df = load_data()

# Extract spoken_languages names
df = extract_name(df, "spoken_languages")

# For spoken_languages
genre_tally = tally_names(df, "spoken_languages_list")
genre_tally.head(10)  # top 10 spoken_languages
# Out:
#         Item  Count
# 0    English   4485
# 1   Français    437
# 2    Español    351
# 3    Deutsch    262
# 4   Italiano    188
# 5    Pусский    185
# 6        普通话    107
# 7        日本語     97
# 8  Português     68
# 9    العربية     67

# %%
from d100project.eda._tally_strings import tally_strings
from d100project.data._load_data import load_data

# load dataset
df = load_data()

# For original_language
tally_strings(df, "original_language").head(10)
# Out:
#   Value  Count
# 0    en   4505
# 1    fr     70
# 2    es     32
# 3    zh     27
# 4    de     27
# 5    hi     19
# 6    ja     16
# 7    it     14
# 8    cn     12
# 9    ko     11

# %%
from d100project.eda._plot_category import plot_category
from d100project.data._load_data import load_data
from d100project.eda._extract_name import extract_name

# Load dataset
df = load_data()

column = "genres"

df = extract_name(df, column)

plot_category(df, column + "_list", "revenue")
# Out:
# /home/gmurp/project/project_repo/d100project/eda/_plot_category.py:56: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend(loc='upper left')

# %%
from d100project.eda._plot_category import plot_category
from d100project.data._load_data import load_data
from d100project.eda._extract_name import extract_name

# Load dataset
df = load_data()

column = "production_countries"

df = extract_name(df, column)

plot_category(df, column + "_list", "revenue")
# Out:
# /home/gmurp/project/project_repo/d100project/eda/_plot_category.py:56: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend(loc='upper left')

# %%
from d100project.eda._plot_category import plot_category
from d100project.data._load_data import load_data
from d100project.eda._extract_name import extract_name

# Load dataset
df = load_data()

column = "production_companies"

df = extract_name(df, column)

plot_category(df, column + "_list", "revenue")
# Out:
# /home/gmurp/project/project_repo/d100project/eda/_plot_category.py:58: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend(loc='upper left')

# %%
from d100project.eda._extract_name import extract_name
from d100project.eda._count_empty_lists import count_empty_lists
from d100project.data._load_data import load_data

# load dataset
df = load_data()

df = extract_name(df, "genres")
count_empty_lists(df, "genres")
# Out:
# Number of missing genres: 28

# %%
from d100project.eda._extract_name import extract_name
from d100project.eda._count_empty_lists import count_empty_lists
from d100project.data._load_data import load_data

# load dataset
df = load_data()

df = extract_name(df, "production_companies")
count_empty_lists(df, "production_companies")
# Out:
# Number of missing production_companies: 351

# %%
from d100project.eda._extract_name import extract_name
from d100project.eda._count_empty_lists import count_empty_lists
from d100project.data._load_data import load_data

# load dataset
df = load_data()

df = extract_name(df, "production_countries")
count_empty_lists(df, "production_countries")
# Out:
# Number of missing production_countries: 174

# %%
from d100project.eda._extract_name import extract_name
from d100project.eda._count_empty_lists import count_empty_lists
from d100project.data._load_data import load_data

# load dataset
df = load_data()

df = extract_name(df, "spoken_languages")
count_empty_lists(df, "spoken_languages")
# Out:
# Number of missing spoken_languages: 86

# %%
from d100project.eda._count_missing_values import count_missing_values
from d100project.data._load_data import load_data

# load dataset
df = load_data()

count_missing_values(df, "budget")
# Out:
# Counting missing values and zeros in column: budget
# np.int64(1037)

# %%
from d100project.eda._count_missing_values import count_missing_values
from d100project.data._load_data import load_data

# load dataset
df = load_data()

count_missing_values(df, "revenue")
# Out:
# Counting missing values and zeros in column: revenue
# np.int64(1427)

# %%
from d100project.eda._count_missing_values import count_missing_values
from d100project.data._load_data import load_data

# load dataset
df = load_data()

count_missing_values(df, "runtime")
# Out:
# Counting missing values and zeros in column: runtime
# np.int64(37)

# %%
from d100project.eda._hist_range import hist_range
from d100project.data._load_data import load_data

# load dataset
df = load_data()

hist_range(df, "budget", min_value=1, max_value=100000, bins=50)
hist_range(df, "revenue", min_value=1, max_value=100000, bins=50)
hist_range(df, "runtime", min_value=1, max_value=30, bins=10)

# %%
from d100project.eda._correlation_matrix import correlation_matrix
from d100project.data._load_data import load_data

# load dataset
df = load_data()

columns = ["budget", "revenue", "runtime", "release_date"]
correlation_matrix(df, columns)

# %%
from d100project.eda._extract_name import extract_name
from d100project.eda._conditional_means import conditional_means
from d100project.data._load_data import load_data

# load dataset
df = load_data()

df = extract_name(df, "genres")
conditional_means(df, "genres_list", "revenue")

df = extract_name(df, "production_companies")
conditional_means(df, "production_companies_list", "revenue")

df = extract_name(df, "production_countries")
conditional_means(df, "production_countries_list", "revenue")

df = extract_name(df, "spoken_languages")
conditional_means(df, "spoken_languages_list", "revenue")
# Out:
# Conditional means of 'revenue' for the top 20 most common items in 'genres_list':
# Animation: 225,693,025
# Adventure: 208,660,204
# Fantasy: 193,354,245
# Family: 162,345,495
# Science Fiction: 152,456,515
# Action: 141,213,098
# War: 84,155,874
# Thriller: 81,044,291
# Mystery: 78,300,927
# Comedy: 71,289,499
# Crime: 66,150,662
# Romance: 60,002,391
# History: 57,523,562
# Drama: 52,116,232
# Music: 48,455,952
# Western: 46,245,965
# Horror: 43,545,076
# Documentary: 9,838,888
# Foreign: 364,652
# TV Movie: 0
# Conditional means of 'revenue' for the top 20 most common items in 'production_companies_list':
# Walt Disney Pictures: 251,607,509
# Dune Entertainment: 233,856,003
# DreamWorks SKG: 182,082,704
# Twentieth Century Fox Film Corporation: 177,284,465
# Village Roadshow Pictures: 166,078,316
# Warner Bros.: 154,093,254
# Paramount Pictures: 143,433,415
# Columbia Pictures: 142,286,740
# Universal Pictures: 136,940,405
# Relativity Media: 125,107,958
# ...
